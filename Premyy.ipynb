# %%
import pandas as pd
matches = pd.read_csv("matches.csv", index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1389, 27)

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["target"] = (matches["result"] == "W").astype("int")
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# 1   1.0       Tottenham  ...  1.0  0.0    0.0    2022   Manchester City
# 2   0.0    Norwich City  ...  1.0  0.0    0.0    2022   Manchester City
# 3   0.0         Arsenal  ...  0.0  0.0    0.0    2022   Manchester City
# 4   0.0  Leicester City  ...  0.0  0.0    0.0    2022   Manchester City
# 6   0.0     Southampton  ...  1.0  0.0    0.0    2022   Manchester City
# ..  ...             ...  ...  ...  ...    ...     ...               ...
# 38  4.0       Tottenham  ...  0.0  0.0    0.0    2021  Sheffield United
# 39  2.0  Crystal Palace  ...  1.0  0.0    0.0    2021  Sheffield United
# 40  0.0         Everton  ...  0.0  0.0    0.0    2021  Sheffield United
# 41  1.0   Newcastle Utd  ...  1.0  0.0    0.0    2021  Sheffield United
# 42  0.0         Burnley  ...  0.0  0.0    0.0    2021  Sheffield United
#
#    venue_code opp_code hour  day_code  target
# 1           0       18   16         6       0
# 2           1       15   15         5       1
# 3           1        0   12         5       1
# 4           0       10   15         5       1
# 6           1       17   15         5       0
# ..        ...      ...  ...       ...     ...
# 38          0       18   19         6       0
# 39          1        6   15         5       0
# 40          0        7   19         6       1
# 41          0       14   18         2       0
# 42          1        4   16         6       1
#
# [1389 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split =10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W  2.0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L  1.0
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W  4.0
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L  2.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
#      ga        opponent  ...   fk   pk  pkatt  season             team  \
# 1   1.0       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City
# 2   0.0    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City
# 3   0.0         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City
# 4   0.0  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City
# 6   0.0     Southampton  ...  1.0  0.0    0.0    2022  Manchester City
# ..  ...             ...  ...  ...  ...    ...     ...              ...
# 54  0.0  Crystal Palace  ...  1.0  0.0    0.0    2021  Manchester City
# 56  2.0         Chelsea  ...  0.0  0.0    1.0    2021  Manchester City
# 57  3.0   Newcastle Utd  ...  1.0  0.0    0.0    2021  Manchester City
# 58  3.0        Brighton  ...  1.0  0.0    0.0    2021  Manchester City
# 59  0.0         Everton  ...  0.0  0.0    0.0    2021  Manchester City
#
#    venue_code opp_code hour  day_code  target
# 1           0       18   16         6       0
# 2           1       15   15         5       1
# 3           1        0   12         5       1
# 4           0       10   15         5       1
# 6           1       17   15         5       0
# ..        ...      ...  ...       ...     ...
# 54          0        6   12         5       1
# 56          1        5   17         5       0
# 57          0       14   20         4       1
# 58          0        3   19         1       0
# 59          1        7   16         6       1
#
# [71 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 5   0.0         Arsenal  ...         5       1    2.000000    2.333333
# 7   1.0        West Ham  ...         5       0    1.333333    2.000000
# 9   0.0   Sheffield Utd  ...         5       1    1.000000    0.666667
# 11  1.0       Liverpool  ...         6       0    1.000000    0.333333
# 12  2.0       Tottenham  ...         5       0    1.000000    0.666667
# ..  ...             ...  ...       ...     ...         ...         ...
# 42  0.0  Crystal Palace  ...         0       0    2.333333    1.333333
# 44  0.0         Burnley  ...         5       1    1.666667    0.333333
# 46  2.0       Liverpool  ...         6       0    2.000000    0.333333
# 49  0.0        Brighton  ...         2       1    1.333333    0.666667
# 50  1.0         Watford  ...         5       1    2.333333    0.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 5   17.333333    4.666667    18.900000   1.333333    0.333333       0.333333
# 7   17.333333    3.666667    17.733333   0.666667    0.000000       0.000000
# 9   16.666667    4.333333    18.233333   0.666667    0.000000       0.000000
# 11  14.333333    6.666667    18.466667   1.000000    0.000000       0.000000
# 12  12.000000    5.666667    19.366667   1.000000    0.000000       0.333333
# ..        ...         ...          ...        ...         ...            ...
# 42  19.000000    7.000000    15.366667   0.333333    0.333333       0.333333
# 44  18.333333    7.333333    16.000000   0.333333    0.000000       0.000000
# 46  20.000000    6.666667    16.133333   0.333333    0.000000       0.000000
# 49  15.666667    4.666667    16.700000   0.333333    0.000000       0.000000
# 50  15.333333    5.000000    17.200000   0.333333    0.000000       0.000000
#
# [68 rows x 40 columns]

# %%
matches_rolling = (
    matches.groupby("team")
    .apply(lambda x: rolling_averages(x, cols, new_cols), include_groups=False)
    .reset_index()  # <— DON'T drop, keeps 'team' as a column
)

# %%
matches_rolling
# Out:
#                          team  level_1       date   time            comp  \
# 0                     Arsenal        6 2020-10-04  14:00  Premier League
# 1                     Arsenal        7 2020-10-17  17:30  Premier League
# 2                     Arsenal        9 2020-10-25  19:15  Premier League
# 3                     Arsenal       11 2020-11-01  16:30  Premier League
# 4                     Arsenal       13 2020-11-08  19:15  Premier League
# ...                       ...      ...        ...    ...             ...
# 1312  Wolverhampton Wanderers       32 2022-03-13  14:00  Premier League
# 1313  Wolverhampton Wanderers       33 2022-03-18  20:00  Premier League
# 1314  Wolverhampton Wanderers       34 2022-04-02  15:00  Premier League
# 1315  Wolverhampton Wanderers       35 2022-04-08  20:00  Premier League
# 1316  Wolverhampton Wanderers       36 2022-04-24  14:00  Premier League
#
#              round  day venue result   gf  ...  day_code target  gf_rolling  \
# 0      Matchweek 4  Sun  Home      W  2.0  ...         6      1    2.000000
# 1      Matchweek 5  Sat  Away      L  0.0  ...         5      0    1.666667
# 2      Matchweek 6  Sun  Home      L  0.0  ...         6      0    1.000000
# 3      Matchweek 7  Sun  Away      W  1.0  ...         6      1    0.666667
# 4      Matchweek 8  Sun  Home      L  0.0  ...         6      0    0.333333
# ...            ...  ...   ...    ...  ...  ...       ...    ...         ...
# 1312  Matchweek 29  Sun  Away      W  1.0  ...         6      1    1.333333
# 1313  Matchweek 30  Fri  Home      L  2.0  ...         4      0    1.666667
# 1314  Matchweek 31  Sat  Home      W  2.0  ...         5      1    2.333333
# 1315  Matchweek 32  Fri  Away      L  0.0  ...         4      0    1.666667
# 1316  Matchweek 34  Sun  Away      L  0.0  ...         6      0    1.333333
#
#       ga_rolling  sh_rolling  sot_rolling dist_rolling fk_rolling pk_rolling  \
# 0       1.333333    7.666667     3.666667    14.733333   0.666667   0.000000
# 1       1.666667    5.333333     3.666667    15.766667   0.000000   0.000000
# 2       1.666667    7.000000     3.666667    16.733333   0.666667   0.000000
# 3       1.000000    9.666667     4.000000    16.033333   1.000000   0.000000
# 4       0.666667    9.666667     2.666667    18.033333   1.000000   0.333333
# ...          ...         ...          ...          ...        ...        ...
# 1312    1.000000   12.333333     3.666667    19.300000   0.000000   0.000000
# 1313    0.666667   12.333333     4.333333    19.600000   0.000000   0.000000
# 1314    1.000000   13.000000     5.333333    19.833333   0.000000   0.000000
# 1315    1.333333   13.000000     5.000000    18.533333   0.000000   0.000000
# 1316    1.666667   10.000000     4.666667    17.633333   0.000000   0.000000
#
#      pkatt_rolling
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.333333
# ...            ...
# 1312      0.000000
# 1313      0.000000
# 1314      0.000000
# 1315      0.000000
# 1316      0.000000
#
# [1317 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#                          team  level_1       date   time            comp  \
# 0                     Arsenal        6 2020-10-04  14:00  Premier League
# 1                     Arsenal        7 2020-10-17  17:30  Premier League
# 2                     Arsenal        9 2020-10-25  19:15  Premier League
# 3                     Arsenal       11 2020-11-01  16:30  Premier League
# 4                     Arsenal       13 2020-11-08  19:15  Premier League
# ...                       ...      ...        ...    ...             ...
# 1312  Wolverhampton Wanderers       32 2022-03-13  14:00  Premier League
# 1313  Wolverhampton Wanderers       33 2022-03-18  20:00  Premier League
# 1314  Wolverhampton Wanderers       34 2022-04-02  15:00  Premier League
# 1315  Wolverhampton Wanderers       35 2022-04-08  20:00  Premier League
# 1316  Wolverhampton Wanderers       36 2022-04-24  14:00  Premier League
#
#              round  day venue result   gf  ...  day_code target  gf_rolling  \
# 0      Matchweek 4  Sun  Home      W  2.0  ...         6      1    2.000000
# 1      Matchweek 5  Sat  Away      L  0.0  ...         5      0    1.666667
# 2      Matchweek 6  Sun  Home      L  0.0  ...         6      0    1.000000
# 3      Matchweek 7  Sun  Away      W  1.0  ...         6      1    0.666667
# 4      Matchweek 8  Sun  Home      L  0.0  ...         6      0    0.333333
# ...            ...  ...   ...    ...  ...  ...       ...    ...         ...
# 1312  Matchweek 29  Sun  Away      W  1.0  ...         6      1    1.333333
# 1313  Matchweek 30  Fri  Home      L  2.0  ...         4      0    1.666667
# 1314  Matchweek 31  Sat  Home      W  2.0  ...         5      1    2.333333
# 1315  Matchweek 32  Fri  Away      L  0.0  ...         4      0    1.666667
# 1316  Matchweek 34  Sun  Away      L  0.0  ...         6      0    1.333333
#
#       ga_rolling  sh_rolling  sot_rolling dist_rolling fk_rolling pk_rolling  \
# 0       1.333333    7.666667     3.666667    14.733333   0.666667   0.000000
# 1       1.666667    5.333333     3.666667    15.766667   0.000000   0.000000
# 2       1.666667    7.000000     3.666667    16.733333   0.666667   0.000000
# 3       1.000000    9.666667     4.000000    16.033333   1.000000   0.000000
# 4       0.666667    9.666667     2.666667    18.033333   1.000000   0.333333
# ...          ...         ...          ...          ...        ...        ...
# 1312    1.000000   12.333333     3.666667    19.300000   0.000000   0.000000
# 1313    0.666667   12.333333     4.333333    19.600000   0.000000   0.000000
# 1314    1.000000   13.000000     5.333333    19.833333   0.000000   0.000000
# 1315    1.333333   13.000000     5.000000    18.533333   0.000000   0.000000
# 1316    1.666667   10.000000     4.666667    17.633333   0.000000   0.000000
#
#      pkatt_rolling
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.333333
# ...            ...
# 1312      0.000000
# 1313      0.000000
# 1314      0.000000
# 1315      0.000000
# 1316      0.000000
#
# [1317 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols) # add new predictors in new_cols.

# %%
precision
# Out:
# 0.625

# %%
combined
# Out:
#       actual  predicted
# 55         0          0
# 56         1          0
# 57         1          0
# 58         1          1
# 59         1          1
# ...      ...        ...
# 1312       1          0
# 1313       0          0
# 1314       1          0
# 1315       0          0
# 1316       0          0
#
# [276 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index = True, right_index = True) # merge in more columns

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          0 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# 58        W
# 59        W
# ...     ...
# 1312      W
# 1313      L
# 1314      W
# 1315      L
# 1316      L
#
# [276 rows x 6 columns]

# %%
class MissingDict(dict): # makes names matchh
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
mapping["Arsenal"] #doesnt change bc of mapping
# Out:
# 'Arsenal'

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          0 2022-01-23                  Arsenal        Burnley
# 56         1          0 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          1 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new team new_team
# 55        D  Arsenal  Arsenal
# 56        W  Arsenal  Arsenal
# 57        W  Arsenal  Arsenal
# 58        W  Arsenal  Arsenal
# 59        W  Arsenal  Arsenal
# ...     ...      ...      ...
# 1312      W   Wolves   Wolves
# 1313      L   Wolves   Wolves
# 1314      W   Wolves   Wolves
# 1315      L   Wolves   Wolves
# 1316      L   Wolves   Wolves
#
# [276 rows x 8 columns]

# %%
merged = combined.merge(combined, left_on = ["date","new_team"], right_on=["date","opponent"]) #merge repeated games see if predictions are the same. merged into same row

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#     result_x new team_x new_team_x  actual_y  predicted_y  \
# 0          D    Arsenal    Arsenal         0            0
# 1          W    Arsenal    Arsenal         0            0
# 2          W    Arsenal    Arsenal         0            0
# 3          W    Arsenal    Arsenal         0            0
# 4          W    Arsenal    Arsenal         0            0
# ..       ...        ...        ...       ...          ...
# 257        W     Wolves     Wolves         0            0
# 258        L     Wolves     Wolves         1            0
# 259        W     Wolves     Wolves         0            0
# 260        L     Wolves     Wolves         1            0
# 261        L     Wolves     Wolves         1            0
#
#                       team_y opponent_y result_y     new team_y     new_team_y
# 0                    Burnley    Arsenal        D        Burnley        Burnley
# 1    Wolverhampton Wanderers    Arsenal        L         Wolves         Wolves
# 2                  Brentford    Arsenal        L      Brentford      Brentford
# 3    Wolverhampton Wanderers    Arsenal        L         Wolves         Wolves
# 4                    Watford    Arsenal        L        Watford        Watford
# ..                       ...        ...      ...            ...            ...
# 257                  Everton     Wolves        L        Everton        Everton
# 258             Leeds United     Wolves        W   Leeds United   Leeds United
# 259              Aston Villa     Wolves        L    Aston Villa    Aston Villa
# 260         Newcastle United     Wolves        W  Newcastle Utd  Newcastle Utd
# 261                  Burnley     Wolves        W        Burnley        Burnley
#
# [262 rows x 15 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()#when model predicted when team would win and team b would lose, what actuallyhppend
# Out:
# actual_x
# 1    27
# 0    13
# Name: count, dtype: int64

# %%
27/40
# Out:
# 0.675
